# %%
# word length output 

imput="Pyhton is Very Very easy language"

out={word:(len(word)) for word in imput.split()}
print(out)
# Out:
# {'Pyhton': 6, 'is': 2, 'Very': 4, 'easy': 4, 'language': 8}

# %%
a= "HeLLo World"

out={char:(ord(char))  for char in a  if char.isupper()}
print(out)
# Out:
# {'H': 72, 'L': 76, 'W': 87}
