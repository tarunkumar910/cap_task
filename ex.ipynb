# %%
# question number 1

nums = [1, 2, 3, 1, 2]

if nums[:2] == nums[-2:]: 

    print("Valid slice")
# Out:
# Valid slice

# %%
def is_valid_slice():
    a=20
    b=50
    return a+b

print(is_valid_slice())
# Out:
# 70

# %%
def count(a):
    odd=0
    even=0

    while a !=0:
        digit = a%10
        if digit%2 ==0:
            even=even+1
        else:
            odd=odd+1
        a=a//10

    return even , odd

count(12345)
# Out:
# (2, 3)

# %%
def palidrom(num):
    temp =num
    rev=0
    while temp !=0:
        rev =rev*10+temp%10
        temp =temp//10

    if rev == num:
        return "pallidrom"
    return "not pallidrom"

palidrom(23432)
# Out:
# 'pallidrom'
